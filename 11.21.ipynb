# %%
f = open("grades.csv", 'r')

# %%
L = f.readlines()
f.close()

# %%
L
# Out:
# ['姓名,國文,英文,數學,自然,社會\n',
#  '劉俊安,9,10,15,10,13\n',
#  '胡玉華,10,10,10,8,9\n',
#  '黃淑婷,13,15,8,11,14\n',
#  '陳上紫,10,10,8,9,14\n',
#  '崔靜成,13,12,14,12,13\n',
#  '張雅岳,13,12,12,12,8\n',
#  '梁俊翔,11,13,10,10,14\n',
#  '林金鳳,8,9,10,10,8\n',
#  '許協旺,9,9,12,10,10\n',
#  '郭雅惠,10,15,12,11,9\n',
#  '張志偉,14,9,8,10,12\n',
#  '周皇樺,13,9,13,14,15\n',
#  '李正偉,11,15,11,14,15\n',
#  '黃旭忠,15,14,9,12,10\n',
#  '葉雅琳,8,13,10,13,14\n',
#  '黃淑慧,11,8,10,12,15\n',
#  '吳芝菁,14,9,11,10,9\n',
#  '聶珮君,12,11,13,12,9\n',
#  '梁慧君,9,8,8,8,12\n',
#  '葉曉玲,14,9,11,15,9\n',
#  '陳智超,13,9,13,14,13\n',
#  '黃奕霞,9,8,11,13,8\n',
#  '沈昆純,12,14,10,9,9\n',
#  '許惠雯,10,13,12,14,10\n',
#  '陳竹伯,10,12,15,10,14\n',
#  '蔡亦瑄,13,13,14,13,12\n',
#  '戴喜寶,13,11,9,14,9\n',
#  '馮白屏,8,13,14,8,10\n',
#  '王金鳳,15,14,8,12,8\n',
#  '闕進綠,14,11,13,8,11\n',
#  '連瑋玲,8,10,14,8,13\n',
#  '林秀娟,15,12,9,9,15\n',
#  '林建亨,9,11,8,8,11\n',
#  '王佳蓉,14,15,9,9,8\n',
#  '曾淑玟,13,12,10,11,9\n',
#  '盧冠宏,14,11,10,11,11\n',
#  '詹威德,12,13,15,10,14\n',
#  '曾怡君,11,12,15,13,14\n',
# ...

# %%
student=L[80]
student
# Out:
# '宣宣士,9,10,12,15,13\n'

# %%
student.rstrip('\n').split(',')
# Out:
# ['宣宣士', '9', '10', '12', '15', '13']

# %%
grades=[]

# %%
for student in L :
    s = student.rstrip('\n').split(',')
    grades.append(s)

# %%
grades
# Out:
# [['姓名', '國文', '英文', '數學', '自然', '社會'],
#  ['劉俊安', '9', '10', '15', '10', '13'],
#  ['胡玉華', '10', '10', '10', '8', '9'],
#  ['黃淑婷', '13', '15', '8', '11', '14'],
#  ['陳上紫', '10', '10', '8', '9', '14'],
#  ['崔靜成', '13', '12', '14', '12', '13'],
#  ['張雅岳', '13', '12', '12', '12', '8'],
#  ['梁俊翔', '11', '13', '10', '10', '14'],
#  ['林金鳳', '8', '9', '10', '10', '8'],
#  ['許協旺', '9', '9', '12', '10', '10'],
#  ['郭雅惠', '10', '15', '12', '11', '9'],
#  ['張志偉', '14', '9', '8', '10', '12'],
#  ['周皇樺', '13', '9', '13', '14', '15'],
#  ['李正偉', '11', '15', '11', '14', '15'],
#  ['黃旭忠', '15', '14', '9', '12', '10'],
#  ['葉雅琳', '8', '13', '10', '13', '14'],
#  ['黃淑慧', '11', '8', '10', '12', '15'],
#  ['吳芝菁', '14', '9', '11', '10', '9'],
#  ['聶珮君', '12', '11', '13', '12', '9'],
#  ['梁慧君', '9', '8', '8', '8', '12'],
#  ['葉曉玲', '14', '9', '11', '15', '9'],
#  ['陳智超', '13', '9', '13', '14', '13'],
#  ['黃奕霞', '9', '8', '11', '13', '8'],
#  ['沈昆純', '12', '14', '10', '9', '9'],
# ...

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("grades.csv")

# %%
df
# Out:
#      姓名  國文  英文  數學  自然  社會
# 0   劉俊安   9  10  15  10  13
# 1   胡玉華  10  10  10   8   9
# 2   黃淑婷  13  15   8  11  14
# 3   陳上紫  10  10   8   9  14
# 4   崔靜成  13  12  14  12  13
# 5   張雅岳  13  12  12  12   8
# 6   梁俊翔  11  13  10  10  14
# 7   林金鳳   8   9  10  10   8
# 8   許協旺   9   9  12  10  10
# 9   郭雅惠  10  15  12  11   9
# 10  張志偉  14   9   8  10  12
# 11  周皇樺  13   9  13  14  15
# 12  李正偉  11  15  11  14  15
# 13  黃旭忠  15  14   9  12  10
# 14  葉雅琳   8  13  10  13  14
# 15  黃淑慧  11   8  10  12  15
# 16  吳芝菁  14   9  11  10   9
# 17  聶珮君  12  11  13  12   9
# 18  梁慧君   9   8   8   8  12
# 19  葉曉玲  14   9  11  15   9
# 20  陳智超  13   9  13  14  13
# 21  黃奕霞   9   8  11  13   8
# 22  沈昆純  12  14  10   9   9
# 23  許惠雯  10  13  12  14  10
# 24  陳竹伯  10  12  15  10  14
# 25  蔡亦瑄  13  13  14  13  12
# 26  戴喜寶  13  11   9  14   9
# 27  馮白屏   8  13  14   8  10
# 28  王金鳳  15  14   8  12   8
# 29  闕進綠  14  11  13   8  11
# ..  ...  ..  ..  ..  ..  ..
# 70  葉儀依   9  13  15   8  14
# ...

# %%
np.mean(df["數學"])
# Out:
# 11.57

# %%
df["數學"].mean()
# Out:
# 11.57

# %%
df.數學.mean()
# Out:
# 11.57

# %%
df.數學.describe()
# Out:
# count    100.000000
# mean      11.570000
# std        2.310516
# min        8.000000
# 25%       10.000000
# 50%       11.000000
# 75%       14.000000
# max       15.000000
# Name: 數學, dtype: float64

# %%
df["加權分數"]=df.數學*1.5+df.英文*2

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  加權分數
# 0  劉俊安   9  10  15  10  13  42.5
# 1  胡玉華  10  10  10   8   9  35.0
# 2  黃淑婷  13  15   8  11  14  42.0
# 3  陳上紫  10  10   8   9  14  32.0
# 4  崔靜成  13  12  14  12  13  45.0

# %%
df.sort_values(["加權分數","數學","社會"],ascending=False)
# Out:
#      姓名  國文  英文  數學  自然  社會  加權分數
# 73  吳志遠  13  15  15   8   8  52.5
# 57  胡淳茜  12  15  14  13  11  51.0
# 83  李士賢  10  14  15  13  13  50.5
# 68  劉麗芬   8  14  14  14  14  49.0
# 66  邱盈俊  10  14  14  13   8  49.0
# 36  詹威德  12  13  15  10  14  48.5
# 70  葉儀依   9  13  15   8  14  48.5
# 80  施雅鈴  13  15  12  13  13  48.0
# 9   郭雅惠  10  15  12  11   9  48.0
# 64  俞志峰   9  14  13  14  15  47.5
# 65  謝雅琳  13  14  13  12   9  47.5
# 87  趙偉希  10  13  14  13  15  47.0
# 44  童心怡  13  13  14   8  13  47.0
# 25  蔡亦瑄  13  13  14  13  12  47.0
# 27  馮白屏   8  13  14   8  10  47.0
# 24  陳竹伯  10  12  15  10  14  46.5
# 37  曾怡君  11  12  15  13  14  46.5
# 76  周育霖   9  12  15  13  12  46.5
# 12  李正偉  11  15  11  14  15  46.5
# 55  林意珍   9  15  11  13   9  46.5
# 48  陳怡婷  15  14  12   9  15  46.0
# 78  葉孟名  12  13  13   9  11  45.5
