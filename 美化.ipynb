# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plot([2011,2012,2013,2014,2015],[22.7,19.6,21.2,23.7,22.4])

# %%
plot([2011,2012,2013,2014,2015],[22.7,19.6,21.2,23.7,22.4], color='green', linestyle='dashed', marker='o',
     markerfacecolor='blue', markersize=12)

# %%
x=[2011,2012,2013,2014,2015]
y=[22.7,19.6,21.2,23.7,22.4]

# %%
plt.plot(x, y, color='black', linestyle='dashed', marker='o', markerfacecolor='red', markersize=12)
plt.xlim(2010.5,2015.5)
plt.ylim(19,24.3)
# Out:
# (19, 24.3)
